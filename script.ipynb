-- %% [markdown]
-- # [dbo].[general_generalparameters]

-- %%
USE [schedulerdb]
GO

-- %%
/****** Object:  Table [dbo].[general_generalparameters]    Script Date: 15/05/2023 10:54:03 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[general_generalparameters](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](200) NOT NULL,
	[description] [nvarchar](max) NULL,
	[registration_date] [datetime2](7) NOT NULL,
	[active] [nvarchar](10) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[general_users]

-- %%
/****** Object:  Table [dbo].[general_users]    Script Date: 15/05/2023 10:54:03 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[general_users](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[last_name] [nvarchar](50) NOT NULL,
	[first_name] [nvarchar](50) NOT NULL,
	[email] [nvarchar](100) NOT NULL,
	[password] [nvarchar](max) NOT NULL,
	[ssn] [nvarchar](20) NOT NULL,
	[dob] [date] NULL,
	[address] [nvarchar](max) NULL,
	[city] [nvarchar](max) NULL,
	[zip] [bigint] NULL,
	[phone] [bigint] NULL,
	[registration_date] [datetime2](7) NOT NULL,
	[deletion_date] [datetime2](7) NULL,
	[active] [nvarchar](10) NOT NULL,
	[deletion_user_id] [int] NULL,
	[profile_id] [int] NULL,
	[registration_user_id] [int] NULL,
	[last_login] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[general_valueparameters]

-- %%
/****** Object:  Table [dbo].[general_valueparameters]    Script Date: 15/05/2023 10:54:03 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[general_valueparameters](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[code] [nvarchar](50) NULL,
	[file] [nvarchar](100) NULL,
	[name] [nvarchar](max) NOT NULL,
	[description] [nvarchar](max) NULL,
	[first_value] [nvarchar](max) NULL,
	[second_value] [nvarchar](max) NULL,
	[third_value] [nvarchar](max) NULL,
	[fourth_value] [nvarchar](max) NULL,
	[fifth] [nvarchar](max) NULL,
	[registration_date] [datetime2](7) NOT NULL,
	[deletion_date] [datetime2](7) NULL,
	[active] [nvarchar](10) NOT NULL,
	[deletion_user_id] [int] NULL,
	[parameter_id] [int] NOT NULL,
	[registration_user_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[general_generalparameters]

-- %%
SET IDENTITY_INSERT [dbo].[general_generalparameters] ON 
INSERT [dbo].[general_generalparameters] ([id], [name], [description], [registration_date], [active]) VALUES (1, N'PERFILES', N'PERFILES2', N'En este grupo se estaran guardando los diferentes perfiles', CAST(N'2023-05-14T03:05:49.4347430' AS DateTime2), N'1')
SET IDENTITY_INSERT [dbo].[general_generalparameters] OFF
GO

-- %% [markdown]
-- # [dbo].[general_users]

-- %%
SET IDENTITY_INSERT [dbo].[general_users] ON 
INSERT [dbo].[general_users] ([id], [last_name], [first_name], [email], [password], [ssn], [dob], [address], [city], [zip], [phone], [registration_date], [deletion_date], [active], [deletion_user_id], [profile_id], [registration_user_id], [last_login]) VALUES (4, N'Admin', N'User', N'admin@gmail.com', N'pbkdf2_sha256$120000$10MDq9dnLIwB$+86iKUD3g6mZXHc3iQ3KrVNzwMYesoaSOAZ1ZmjosLU=', N'123456789', NULL, NULL, NULL, NULL, NULL, CAST(N'2023-05-14T02:36:06.7128090' AS DateTime2), NULL, N'1', NULL, 2, NULL, CAST(N'2023-05-15T22:19:46.2878210' AS DateTime2))
INSERT [dbo].[general_users] ([id], [last_name], [first_name], [email], [password], [ssn], [dob], [address], [city], [zip], [phone], [registration_date], [deletion_date], [active], [deletion_user_id], [profile_id], [registration_user_id], [last_login]) VALUES (1010, N'Peña', N'Maira', N'maira@gmail.com', N'pbkdf2_sha256$120000$VB8rWWgfVWvr$sU6CjZY801+nP/ReCyn74094G8VVs36DfK5VdJ7Aog8=', N'678909789', CAST(N'2000-04-04' AS Date), N'vvvvv', N'vvvvvvv', 444, 44444, CAST(N'2023-05-16T03:00:39.3281760' AS DateTime2), NULL, N'1', NULL, 1, 4, NULL)
SET IDENTITY_INSERT [dbo].[general_users] OFF
GO

-- %% [markdown]
-- # [dbo].[general_valueparameters]

-- %%
SET IDENTITY_INSERT [dbo].[general_valueparameters] ON 
INSERT [dbo].[general_valueparameters] ([id], [code], [file], [name], [description], [first_value], [second_value], [third_value], [fourth_value], [fifth], [registration_date], [deletion_date], [active], [deletion_user_id], [parameter_id], [registration_user_id]) VALUES (1, N'driver_user', N'', N'DRIVER', NULL, NULL, NULL, NULL, NULL, NULL, CAST(N'2023-05-14T03:51:50.0566160' AS DateTime2), NULL, N'1', NULL, 1, NULL)
INSERT [dbo].[general_valueparameters] ([id], [code], [file], [name], [description], [first_value], [second_value], [third_value], [fourth_value], [fifth], [registration_date], [deletion_date], [active], [deletion_user_id], [parameter_id], [registration_user_id]) VALUES (2, N'admin_user', N'', N'ADMIN', NULL, NULL, NULL, NULL, NULL, NULL, CAST(N'2023-05-14T03:52:05.8795650' AS DateTime2), NULL, N'1', NULL, 1, NULL)
INSERT [dbo].[general_valueparameters] ([id], [code], [file], [name], [description], [first_value], [second_value], [third_value], [fourth_value], [fifth], [registration_date], [deletion_date], [active], [deletion_user_id], [parameter_id], [registration_user_id]) VALUES (3, NULL, N'', N'Random', NULL, NULL, NULL, NULL, NULL, NULL, CAST(N'2023-05-14T03:52:18.3803920' AS DateTime2), CAST(N'2023-05-13T22:53:19.1717720' AS DateTime2), N'0', 4, 1, NULL)
SET IDENTITY_INSERT [dbo].[general_valueparameters] OFF
GO

-- %% [markdown]
-- # [UQ__general___AB6E616459B9A28E]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__general___AB6E616459B9A28E]    Script Date: 15/05/2023 10:54:03 p. m. ******/
ALTER TABLE [dbo].[general_users] ADD UNIQUE NONCLUSTERED 
(
	[email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__general___DDDF0AE68768BCF7]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__general___DDDF0AE68768BCF7]    Script Date: 15/05/2023 10:54:03 p. m. ******/
ALTER TABLE [dbo].[general_users] ADD UNIQUE NONCLUSTERED 
(
	[ssn] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [general_users_deletion_user_id_ec548bf9_fk_general_users_id]

-- %%
ALTER TABLE [dbo].[general_users]  WITH CHECK ADD  CONSTRAINT [general_users_deletion_user_id_ec548bf9_fk_general_users_id] FOREIGN KEY([deletion_user_id])
REFERENCES [dbo].[general_users] ([id])
GO
ALTER TABLE [dbo].[general_users] CHECK CONSTRAINT [general_users_deletion_user_id_ec548bf9_fk_general_users_id]
GO

-- %% [markdown]
-- # [general_users_profile_id_bf09f467_fk_general_valueparameters_id]

-- %%
ALTER TABLE [dbo].[general_users]  WITH CHECK ADD  CONSTRAINT [general_users_profile_id_bf09f467_fk_general_valueparameters_id] FOREIGN KEY([profile_id])
REFERENCES [dbo].[general_valueparameters] ([id])
GO
ALTER TABLE [dbo].[general_users] CHECK CONSTRAINT [general_users_profile_id_bf09f467_fk_general_valueparameters_id]
GO

-- %% [markdown]
-- # [general_users_registration_user_id_310495e7_fk_general_users_id]

-- %%
ALTER TABLE [dbo].[general_users]  WITH CHECK ADD  CONSTRAINT [general_users_registration_user_id_310495e7_fk_general_users_id] FOREIGN KEY([registration_user_id])
REFERENCES [dbo].[general_users] ([id])
GO
ALTER TABLE [dbo].[general_users] CHECK CONSTRAINT [general_users_registration_user_id_310495e7_fk_general_users_id]
GO

-- %% [markdown]
-- # [general_valueparameters_deletion_user_id_15d7af40_fk_general_users_id]

-- %%
ALTER TABLE [dbo].[general_valueparameters]  WITH CHECK ADD  CONSTRAINT [general_valueparameters_deletion_user_id_15d7af40_fk_general_users_id] FOREIGN KEY([deletion_user_id])
REFERENCES [dbo].[general_users] ([id])
GO
ALTER TABLE [dbo].[general_valueparameters] CHECK CONSTRAINT [general_valueparameters_deletion_user_id_15d7af40_fk_general_users_id]
GO

-- %% [markdown]
-- # [general_valueparameters_parameter_id_8c43d2da_fk_general_generalparameters_id]

-- %%
ALTER TABLE [dbo].[general_valueparameters]  WITH CHECK ADD  CONSTRAINT [general_valueparameters_parameter_id_8c43d2da_fk_general_generalparameters_id] FOREIGN KEY([parameter_id])
REFERENCES [dbo].[general_generalparameters] ([id])
GO
ALTER TABLE [dbo].[general_valueparameters] CHECK CONSTRAINT [general_valueparameters_parameter_id_8c43d2da_fk_general_generalparameters_id]
GO

-- %% [markdown]
-- # [general_valueparameters_registration_user_id_e4fa7d8e_fk_general_users_id]

-- %%
ALTER TABLE [dbo].[general_valueparameters]  WITH CHECK ADD  CONSTRAINT [general_valueparameters_registration_user_id_e4fa7d8e_fk_general_users_id] FOREIGN KEY([registration_user_id])
REFERENCES [dbo].[general_users] ([id])
GO
ALTER TABLE [dbo].[general_valueparameters] CHECK CONSTRAINT [general_valueparameters_registration_user_id_e4fa7d8e_fk_general_users_id]
GO
